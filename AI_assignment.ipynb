# %% [markdown]
# <a href="https://colab.research.google.com/github/sunflower2218/calculator_new/blob/master/AI_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-

# %matplotlib
# %matplotlib inline
import os
os.chdir('/content')

# !python Chap_12_Reinforced_Learning_Training.py
# Out:
# Using matplotlib backend: <object object at 0x7f87b852f460>
# 2023-05-30 04:00:21.365501: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-30 04:00:22.373792: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-05-30 04:00:24.009281: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:00:24.460177: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:00:24.460462: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:00:24.471021: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:00:24.471243: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:00:24.471419: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:00:27.063236: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:00:27.063532: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:00:27.063707: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-05-30 04:00:27.063857: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2023-05-30 04:00:27.063903: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13664 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 트레이닝을 시작합니다.
# /content/Chap_12_Reinforced_Learning_Training.py:168: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.gameOver = np.empty(self.maxMemory, dtype = np.bool)
# 2023-05-30 04:00:29.979090: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x42eb4a10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-05-30 04:00:29.979135: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2023-05-30 04:00:30.516019: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8700
# 2023-05-30 04:00:31.028789: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f24d4ab0310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0530 04:00:31.410463 139797957392192 polymorphic_function.py:156] 5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7f24d4ab0310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f24d4ab0310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# W0530 04:00:31.518868 139797957392192 polymorphic_function.py:156] 6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7f24d4ab0310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 반복(Epoch): 0, 에러(err): 0.0131, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# 반복(Epoch): 1, 에러(err): 0.1121, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# /content/model.ckpt-1 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 2, 에러(err): 0.1531, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# 반복(Epoch): 3, 에러(err): 0.2068, 승리횟수(Win count): 0, 승리비율(Win ratio): 0.0000
# 반복(Epoch): 4, 에러(err): 0.2088, 승리횟수(Win count): 1, 승리비율(Win ratio): 20.0000
# 반복(Epoch): 5, 에러(err): 0.2943, 승리횟수(Win count): 2, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 6, 에러(err): 0.4129, 승리횟수(Win count): 3, 승리비율(Win ratio): 42.8571
# 반복(Epoch): 7, 에러(err): 0.3932, 승리횟수(Win count): 3, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 8, 에러(err): 0.3402, 승리횟수(Win count): 4, 승리비율(Win ratio): 44.4444
# 반복(Epoch): 9, 에러(err): 0.4120, 승리횟수(Win count): 4, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 10, 에러(err): 0.3432, 승리횟수(Win count): 4, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 11, 에러(err): 0.3589, 승리횟수(Win count): 4, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 12, 에러(err): 0.4120, 승리횟수(Win count): 4, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 13, 에러(err): 0.3273, 승리횟수(Win count): 4, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 14, 에러(err): 0.4578, 승리횟수(Win count): 5, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 15, 에러(err): 0.3530, 승리횟수(Win count): 5, 승리비율(Win ratio): 31.2500
# 반복(Epoch): 16, 에러(err): 0.4410, 승리횟수(Win count): 5, 승리비율(Win ratio): 29.4118
# 반복(Epoch): 17, 에러(err): 0.4760, 승리횟수(Win count): 5, 승리비율(Win ratio): 27.7778
# 반복(Epoch): 18, 에러(err): 0.5031, 승리횟수(Win count): 5, 승리비율(Win ratio): 26.3158
# 반복(Epoch): 19, 에러(err): 0.4588, 승리횟수(Win count): 6, 승리비율(Win ratio): 30.0000
# 반복(Epoch): 20, 에러(err): 0.3481, 승리횟수(Win count): 6, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 21, 에러(err): 0.3424, 승리횟수(Win count): 7, 승리비율(Win ratio): 31.8182
# 반복(Epoch): 22, 에러(err): 0.3139, 승리횟수(Win count): 7, 승리비율(Win ratio): 30.4348
# 반복(Epoch): 23, 에러(err): 0.3921, 승리횟수(Win count): 7, 승리비율(Win ratio): 29.1667
# 반복(Epoch): 24, 에러(err): 0.3274, 승리횟수(Win count): 8, 승리비율(Win ratio): 32.0000
# 반복(Epoch): 25, 에러(err): 0.4022, 승리횟수(Win count): 8, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 26, 에러(err): 0.3264, 승리횟수(Win count): 8, 승리비율(Win ratio): 29.6296
# 반복(Epoch): 27, 에러(err): 0.3755, 승리횟수(Win count): 9, 승리비율(Win ratio): 32.1429
# 반복(Epoch): 28, 에러(err): 0.2498, 승리횟수(Win count): 9, 승리비율(Win ratio): 31.0345
# 반복(Epoch): 29, 에러(err): 0.4005, 승리횟수(Win count): 10, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 30, 에러(err): 0.3818, 승리횟수(Win count): 10, 승리비율(Win ratio): 32.2581
# 반복(Epoch): 31, 에러(err): 0.3553, 승리횟수(Win count): 10, 승리비율(Win ratio): 31.2500
# 반복(Epoch): 32, 에러(err): 0.3882, 승리횟수(Win count): 11, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 33, 에러(err): 0.3307, 승리횟수(Win count): 11, 승리비율(Win ratio): 32.3529
# 반복(Epoch): 34, 에러(err): 0.3422, 승리횟수(Win count): 11, 승리비율(Win ratio): 31.4286
# 반복(Epoch): 35, 에러(err): 0.3406, 승리횟수(Win count): 12, 승리비율(Win ratio): 33.3333
# 반복(Epoch): 36, 에러(err): 0.4144, 승리횟수(Win count): 12, 승리비율(Win ratio): 32.4324
# 반복(Epoch): 37, 에러(err): 0.3454, 승리횟수(Win count): 12, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 38, 에러(err): 0.4040, 승리횟수(Win count): 12, 승리비율(Win ratio): 30.7692
# 반복(Epoch): 39, 에러(err): 0.3117, 승리횟수(Win count): 13, 승리비율(Win ratio): 32.5000
# 반복(Epoch): 40, 에러(err): 0.3785, 승리횟수(Win count): 13, 승리비율(Win ratio): 31.7073
# 반복(Epoch): 41, 에러(err): 0.2840, 승리횟수(Win count): 13, 승리비율(Win ratio): 30.9524
# 반복(Epoch): 42, 에러(err): 0.2794, 승리횟수(Win count): 13, 승리비율(Win ratio): 30.2326
# 반복(Epoch): 43, 에러(err): 0.2886, 승리횟수(Win count): 13, 승리비율(Win ratio): 29.5455
# 반복(Epoch): 44, 에러(err): 0.3267, 승리횟수(Win count): 13, 승리비율(Win ratio): 28.8889
# 반복(Epoch): 45, 에러(err): 0.3215, 승리횟수(Win count): 13, 승리비율(Win ratio): 28.2609
# 반복(Epoch): 46, 에러(err): 0.3036, 승리횟수(Win count): 13, 승리비율(Win ratio): 27.6596
# 반복(Epoch): 47, 에러(err): 0.3716, 승리횟수(Win count): 14, 승리비율(Win ratio): 29.1667
# 반복(Epoch): 48, 에러(err): 0.3729, 승리횟수(Win count): 14, 승리비율(Win ratio): 28.5714
# 반복(Epoch): 49, 에러(err): 0.2941, 승리횟수(Win count): 14, 승리비율(Win ratio): 28.0000
# 반복(Epoch): 50, 에러(err): 0.3899, 승리횟수(Win count): 14, 승리비율(Win ratio): 27.4510
# 반복(Epoch): 51, 에러(err): 0.2556, 승리횟수(Win count): 15, 승리비율(Win ratio): 28.8462
# 반복(Epoch): 52, 에러(err): 0.3056, 승리횟수(Win count): 16, 승리비율(Win ratio): 30.1887
# 반복(Epoch): 53, 에러(err): 0.3431, 승리횟수(Win count): 16, 승리비율(Win ratio): 29.6296
# 반복(Epoch): 54, 에러(err): 0.3176, 승리횟수(Win count): 16, 승리비율(Win ratio): 29.0909
# 반복(Epoch): 55, 에러(err): 0.3432, 승리횟수(Win count): 17, 승리비율(Win ratio): 30.3571
# 반복(Epoch): 56, 에러(err): 0.3702, 승리횟수(Win count): 18, 승리비율(Win ratio): 31.5789
# 반복(Epoch): 57, 에러(err): 0.3701, 승리횟수(Win count): 19, 승리비율(Win ratio): 32.7586
# 반복(Epoch): 58, 에러(err): 0.3926, 승리횟수(Win count): 20, 승리비율(Win ratio): 33.8983
# 반복(Epoch): 59, 에러(err): 0.2920, 승리횟수(Win count): 21, 승리비율(Win ratio): 35.0000
# 반복(Epoch): 60, 에러(err): 0.2989, 승리횟수(Win count): 22, 승리비율(Win ratio): 36.0656
# 반복(Epoch): 61, 에러(err): 0.2672, 승리횟수(Win count): 22, 승리비율(Win ratio): 35.4839
# 반복(Epoch): 62, 에러(err): 0.3192, 승리횟수(Win count): 22, 승리비율(Win ratio): 34.9206
# 반복(Epoch): 63, 에러(err): 0.2771, 승리횟수(Win count): 22, 승리비율(Win ratio): 34.3750
# 반복(Epoch): 64, 에러(err): 0.2939, 승리횟수(Win count): 22, 승리비율(Win ratio): 33.8462
# 반복(Epoch): 65, 에러(err): 0.3207, 승리횟수(Win count): 23, 승리비율(Win ratio): 34.8485
# 반복(Epoch): 66, 에러(err): 0.2892, 승리횟수(Win count): 24, 승리비율(Win ratio): 35.8209
# 반복(Epoch): 67, 에러(err): 0.3566, 승리횟수(Win count): 25, 승리비율(Win ratio): 36.7647
# 반복(Epoch): 68, 에러(err): 0.3258, 승리횟수(Win count): 26, 승리비율(Win ratio): 37.6812
# 반복(Epoch): 69, 에러(err): 0.3209, 승리횟수(Win count): 26, 승리비율(Win ratio): 37.1429
# 반복(Epoch): 70, 에러(err): 0.4140, 승리횟수(Win count): 27, 승리비율(Win ratio): 38.0282
# 반복(Epoch): 71, 에러(err): 0.2834, 승리횟수(Win count): 27, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 72, 에러(err): 0.2861, 승리횟수(Win count): 28, 승리비율(Win ratio): 38.3562
# 반복(Epoch): 73, 에러(err): 0.2989, 승리횟수(Win count): 29, 승리비율(Win ratio): 39.1892
# 반복(Epoch): 74, 에러(err): 0.2941, 승리횟수(Win count): 30, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 75, 에러(err): 0.3844, 승리횟수(Win count): 30, 승리비율(Win ratio): 39.4737
# 반복(Epoch): 76, 에러(err): 0.2912, 승리횟수(Win count): 30, 승리비율(Win ratio): 38.9610
# 반복(Epoch): 77, 에러(err): 0.3008, 승리횟수(Win count): 31, 승리비율(Win ratio): 39.7436
# 반복(Epoch): 78, 에러(err): 0.3283, 승리횟수(Win count): 31, 승리비율(Win ratio): 39.2405
# 반복(Epoch): 79, 에러(err): 0.2528, 승리횟수(Win count): 32, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 80, 에러(err): 0.3014, 승리횟수(Win count): 32, 승리비율(Win ratio): 39.5062
# 반복(Epoch): 81, 에러(err): 0.2967, 승리횟수(Win count): 32, 승리비율(Win ratio): 39.0244
# 반복(Epoch): 82, 에러(err): 0.3671, 승리횟수(Win count): 33, 승리비율(Win ratio): 39.7590
# 반복(Epoch): 83, 에러(err): 0.3209, 승리횟수(Win count): 34, 승리비율(Win ratio): 40.4762
# 반복(Epoch): 84, 에러(err): 0.2948, 승리횟수(Win count): 34, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 85, 에러(err): 0.2878, 승리횟수(Win count): 35, 승리비율(Win ratio): 40.6977
# 반복(Epoch): 86, 에러(err): 0.3633, 승리횟수(Win count): 35, 승리비율(Win ratio): 40.2299
# 반복(Epoch): 87, 에러(err): 0.3074, 승리횟수(Win count): 35, 승리비율(Win ratio): 39.7727
# 반복(Epoch): 88, 에러(err): 0.3951, 승리횟수(Win count): 35, 승리비율(Win ratio): 39.3258
# 반복(Epoch): 89, 에러(err): 0.3040, 승리횟수(Win count): 35, 승리비율(Win ratio): 38.8889
# 반복(Epoch): 90, 에러(err): 0.2665, 승리횟수(Win count): 35, 승리비율(Win ratio): 38.4615
# 반복(Epoch): 91, 에러(err): 0.3468, 승리횟수(Win count): 35, 승리비율(Win ratio): 38.0435
# 반복(Epoch): 92, 에러(err): 0.3592, 승리횟수(Win count): 35, 승리비율(Win ratio): 37.6344
# 반복(Epoch): 93, 에러(err): 0.3264, 승리횟수(Win count): 35, 승리비율(Win ratio): 37.2340
# 반복(Epoch): 94, 에러(err): 0.4135, 승리횟수(Win count): 35, 승리비율(Win ratio): 36.8421
# 반복(Epoch): 95, 에러(err): 0.3191, 승리횟수(Win count): 36, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 96, 에러(err): 0.3643, 승리횟수(Win count): 36, 승리비율(Win ratio): 37.1134
# 반복(Epoch): 97, 에러(err): 0.3086, 승리횟수(Win count): 37, 승리비율(Win ratio): 37.7551
# 반복(Epoch): 98, 에러(err): 0.2936, 승리횟수(Win count): 38, 승리비율(Win ratio): 38.3838
# 반복(Epoch): 99, 에러(err): 0.3078, 승리횟수(Win count): 39, 승리비율(Win ratio): 39.0000
# 반복(Epoch): 100, 에러(err): 0.2591, 승리횟수(Win count): 39, 승리비율(Win ratio): 38.6139
# 반복(Epoch): 101, 에러(err): 0.2551, 승리횟수(Win count): 39, 승리비율(Win ratio): 38.2353
# /content/model.ckpt-101 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 102, 에러(err): 0.3202, 승리횟수(Win count): 40, 승리비율(Win ratio): 38.8350
# 반복(Epoch): 103, 에러(err): 0.2944, 승리횟수(Win count): 41, 승리비율(Win ratio): 39.4231
# 반복(Epoch): 104, 에러(err): 0.2549, 승리횟수(Win count): 41, 승리비율(Win ratio): 39.0476
# 반복(Epoch): 105, 에러(err): 0.2702, 승리횟수(Win count): 41, 승리비율(Win ratio): 38.6792
# 반복(Epoch): 106, 에러(err): 0.2564, 승리횟수(Win count): 42, 승리비율(Win ratio): 39.2523
# 반복(Epoch): 107, 에러(err): 0.2022, 승리횟수(Win count): 42, 승리비율(Win ratio): 38.8889
# 반복(Epoch): 108, 에러(err): 0.2664, 승리횟수(Win count): 42, 승리비율(Win ratio): 38.5321
# 반복(Epoch): 109, 에러(err): 0.2256, 승리횟수(Win count): 43, 승리비율(Win ratio): 39.0909
# 반복(Epoch): 110, 에러(err): 0.2081, 승리횟수(Win count): 44, 승리비율(Win ratio): 39.6396
# 반복(Epoch): 111, 에러(err): 0.2213, 승리횟수(Win count): 44, 승리비율(Win ratio): 39.2857
# 반복(Epoch): 112, 에러(err): 0.2236, 승리횟수(Win count): 45, 승리비율(Win ratio): 39.8230
# 반복(Epoch): 113, 에러(err): 0.2360, 승리횟수(Win count): 45, 승리비율(Win ratio): 39.4737
# 반복(Epoch): 114, 에러(err): 0.2565, 승리횟수(Win count): 45, 승리비율(Win ratio): 39.1304
# 반복(Epoch): 115, 에러(err): 0.2921, 승리횟수(Win count): 45, 승리비율(Win ratio): 38.7931
# 반복(Epoch): 116, 에러(err): 0.1978, 승리횟수(Win count): 45, 승리비율(Win ratio): 38.4615
# 반복(Epoch): 117, 에러(err): 0.2569, 승리횟수(Win count): 46, 승리비율(Win ratio): 38.9831
# 반복(Epoch): 118, 에러(err): 0.2293, 승리횟수(Win count): 46, 승리비율(Win ratio): 38.6555
# 반복(Epoch): 119, 에러(err): 0.2188, 승리횟수(Win count): 46, 승리비율(Win ratio): 38.3333
# 반복(Epoch): 120, 에러(err): 0.2143, 승리횟수(Win count): 46, 승리비율(Win ratio): 38.0165
# 반복(Epoch): 121, 에러(err): 0.2569, 승리횟수(Win count): 46, 승리비율(Win ratio): 37.7049
# 반복(Epoch): 122, 에러(err): 0.2110, 승리횟수(Win count): 46, 승리비율(Win ratio): 37.3984
# 반복(Epoch): 123, 에러(err): 0.2197, 승리횟수(Win count): 46, 승리비율(Win ratio): 37.0968
# 반복(Epoch): 124, 에러(err): 0.2460, 승리횟수(Win count): 46, 승리비율(Win ratio): 36.8000
# 반복(Epoch): 125, 에러(err): 0.1990, 승리횟수(Win count): 46, 승리비율(Win ratio): 36.5079
# 반복(Epoch): 126, 에러(err): 0.2871, 승리횟수(Win count): 46, 승리비율(Win ratio): 36.2205
# 반복(Epoch): 127, 에러(err): 0.1903, 승리횟수(Win count): 47, 승리비율(Win ratio): 36.7188
# 반복(Epoch): 128, 에러(err): 0.2760, 승리횟수(Win count): 47, 승리비율(Win ratio): 36.4341
# 반복(Epoch): 129, 에러(err): 0.2747, 승리횟수(Win count): 47, 승리비율(Win ratio): 36.1538
# 반복(Epoch): 130, 에러(err): 0.2033, 승리횟수(Win count): 48, 승리비율(Win ratio): 36.6412
# 반복(Epoch): 131, 에러(err): 0.2724, 승리횟수(Win count): 48, 승리비율(Win ratio): 36.3636
# 반복(Epoch): 132, 에러(err): 0.2250, 승리횟수(Win count): 48, 승리비율(Win ratio): 36.0902
# 반복(Epoch): 133, 에러(err): 0.2039, 승리횟수(Win count): 48, 승리비율(Win ratio): 35.8209
# 반복(Epoch): 134, 에러(err): 0.3282, 승리횟수(Win count): 49, 승리비율(Win ratio): 36.2963
# 반복(Epoch): 135, 에러(err): 0.2101, 승리횟수(Win count): 49, 승리비율(Win ratio): 36.0294
# 반복(Epoch): 136, 에러(err): 0.2031, 승리횟수(Win count): 49, 승리비율(Win ratio): 35.7664
# 반복(Epoch): 137, 에러(err): 0.1583, 승리횟수(Win count): 50, 승리비율(Win ratio): 36.2319
# 반복(Epoch): 138, 에러(err): 0.2067, 승리횟수(Win count): 51, 승리비율(Win ratio): 36.6906
# 반복(Epoch): 139, 에러(err): 0.2818, 승리횟수(Win count): 52, 승리비율(Win ratio): 37.1429
# 반복(Epoch): 140, 에러(err): 0.1385, 승리횟수(Win count): 52, 승리비율(Win ratio): 36.8794
# 반복(Epoch): 141, 에러(err): 0.2565, 승리횟수(Win count): 53, 승리비율(Win ratio): 37.3239
# 반복(Epoch): 142, 에러(err): 0.2174, 승리횟수(Win count): 53, 승리비율(Win ratio): 37.0629
# 반복(Epoch): 143, 에러(err): 0.2561, 승리횟수(Win count): 54, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 144, 에러(err): 0.1987, 승리횟수(Win count): 54, 승리비율(Win ratio): 37.2414
# 반복(Epoch): 145, 에러(err): 0.2089, 승리횟수(Win count): 54, 승리비율(Win ratio): 36.9863
# 반복(Epoch): 146, 에러(err): 0.1642, 승리횟수(Win count): 54, 승리비율(Win ratio): 36.7347
# 반복(Epoch): 147, 에러(err): 0.2457, 승리횟수(Win count): 55, 승리비율(Win ratio): 37.1622
# 반복(Epoch): 148, 에러(err): 0.2416, 승리횟수(Win count): 55, 승리비율(Win ratio): 36.9128
# 반복(Epoch): 149, 에러(err): 0.2619, 승리횟수(Win count): 55, 승리비율(Win ratio): 36.6667
# 반복(Epoch): 150, 에러(err): 0.1660, 승리횟수(Win count): 55, 승리비율(Win ratio): 36.4238
# 반복(Epoch): 151, 에러(err): 0.2436, 승리횟수(Win count): 55, 승리비율(Win ratio): 36.1842
# 반복(Epoch): 152, 에러(err): 0.3035, 승리횟수(Win count): 55, 승리비율(Win ratio): 35.9477
# 반복(Epoch): 153, 에러(err): 0.1828, 승리횟수(Win count): 55, 승리비율(Win ratio): 35.7143
# 반복(Epoch): 154, 에러(err): 0.1753, 승리횟수(Win count): 56, 승리비율(Win ratio): 36.1290
# 반복(Epoch): 155, 에러(err): 0.2073, 승리횟수(Win count): 56, 승리비율(Win ratio): 35.8974
# 반복(Epoch): 156, 에러(err): 0.2565, 승리횟수(Win count): 56, 승리비율(Win ratio): 35.6688
# 반복(Epoch): 157, 에러(err): 0.2696, 승리횟수(Win count): 56, 승리비율(Win ratio): 35.4430
# 반복(Epoch): 158, 에러(err): 0.2240, 승리횟수(Win count): 56, 승리비율(Win ratio): 35.2201
# 반복(Epoch): 159, 에러(err): 0.2555, 승리횟수(Win count): 57, 승리비율(Win ratio): 35.6250
# 반복(Epoch): 160, 에러(err): 0.1670, 승리횟수(Win count): 58, 승리비율(Win ratio): 36.0248
# 반복(Epoch): 161, 에러(err): 0.2267, 승리횟수(Win count): 59, 승리비율(Win ratio): 36.4198
# 반복(Epoch): 162, 에러(err): 0.2124, 승리횟수(Win count): 60, 승리비율(Win ratio): 36.8098
# 반복(Epoch): 163, 에러(err): 0.1784, 승리횟수(Win count): 61, 승리비율(Win ratio): 37.1951
# 반복(Epoch): 164, 에러(err): 0.2187, 승리횟수(Win count): 61, 승리비율(Win ratio): 36.9697
# 반복(Epoch): 165, 에러(err): 0.1624, 승리횟수(Win count): 61, 승리비율(Win ratio): 36.7470
# 반복(Epoch): 166, 에러(err): 0.2743, 승리횟수(Win count): 62, 승리비율(Win ratio): 37.1257
# 반복(Epoch): 167, 에러(err): 0.2087, 승리횟수(Win count): 63, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 168, 에러(err): 0.1858, 승리횟수(Win count): 63, 승리비율(Win ratio): 37.2781
# 반복(Epoch): 169, 에러(err): 0.2158, 승리횟수(Win count): 63, 승리비율(Win ratio): 37.0588
# 반복(Epoch): 170, 에러(err): 0.2419, 승리횟수(Win count): 63, 승리비율(Win ratio): 36.8421
# 반복(Epoch): 171, 에러(err): 0.2760, 승리횟수(Win count): 63, 승리비율(Win ratio): 36.6279
# 반복(Epoch): 172, 에러(err): 0.1903, 승리횟수(Win count): 64, 승리비율(Win ratio): 36.9942
# 반복(Epoch): 173, 에러(err): 0.2072, 승리횟수(Win count): 64, 승리비율(Win ratio): 36.7816
# 반복(Epoch): 174, 에러(err): 0.2347, 승리횟수(Win count): 65, 승리비율(Win ratio): 37.1429
# 반복(Epoch): 175, 에러(err): 0.1743, 승리횟수(Win count): 65, 승리비율(Win ratio): 36.9318
# 반복(Epoch): 176, 에러(err): 0.2715, 승리횟수(Win count): 65, 승리비율(Win ratio): 36.7232
# 반복(Epoch): 177, 에러(err): 0.2260, 승리횟수(Win count): 65, 승리비율(Win ratio): 36.5169
# 반복(Epoch): 178, 에러(err): 0.2759, 승리횟수(Win count): 65, 승리비율(Win ratio): 36.3128
# 반복(Epoch): 179, 에러(err): 0.2558, 승리횟수(Win count): 66, 승리비율(Win ratio): 36.6667
# 반복(Epoch): 180, 에러(err): 0.3114, 승리횟수(Win count): 66, 승리비율(Win ratio): 36.4641
# 반복(Epoch): 181, 에러(err): 0.2119, 승리횟수(Win count): 66, 승리비율(Win ratio): 36.2637
# 반복(Epoch): 182, 에러(err): 0.3789, 승리횟수(Win count): 67, 승리비율(Win ratio): 36.6120
# 반복(Epoch): 183, 에러(err): 0.3272, 승리횟수(Win count): 67, 승리비율(Win ratio): 36.4130
# 반복(Epoch): 184, 에러(err): 0.2511, 승리횟수(Win count): 68, 승리비율(Win ratio): 36.7568
# 반복(Epoch): 185, 에러(err): 0.3853, 승리횟수(Win count): 68, 승리비율(Win ratio): 36.5591
# 반복(Epoch): 186, 에러(err): 0.5293, 승리횟수(Win count): 69, 승리비율(Win ratio): 36.8984
# 반복(Epoch): 187, 에러(err): 0.2016, 승리횟수(Win count): 70, 승리비율(Win ratio): 37.2340
# 반복(Epoch): 188, 에러(err): 0.2125, 승리횟수(Win count): 71, 승리비율(Win ratio): 37.5661
# 반복(Epoch): 189, 에러(err): 0.1046, 승리횟수(Win count): 72, 승리비율(Win ratio): 37.8947
# 반복(Epoch): 190, 에러(err): 0.2463, 승리횟수(Win count): 72, 승리비율(Win ratio): 37.6963
# 반복(Epoch): 191, 에러(err): 0.1566, 승리횟수(Win count): 72, 승리비율(Win ratio): 37.5000
# 반복(Epoch): 192, 에러(err): 0.3302, 승리횟수(Win count): 73, 승리비율(Win ratio): 37.8238
# 반복(Epoch): 193, 에러(err): 0.2308, 승리횟수(Win count): 74, 승리비율(Win ratio): 38.1443
# 반복(Epoch): 194, 에러(err): 0.1481, 승리횟수(Win count): 74, 승리비율(Win ratio): 37.9487
# 반복(Epoch): 195, 에러(err): 0.3695, 승리횟수(Win count): 74, 승리비율(Win ratio): 37.7551
# 반복(Epoch): 196, 에러(err): 0.1573, 승리횟수(Win count): 75, 승리비율(Win ratio): 38.0711
# 반복(Epoch): 197, 에러(err): 0.2623, 승리횟수(Win count): 76, 승리비율(Win ratio): 38.3838
# 반복(Epoch): 198, 에러(err): 0.2798, 승리횟수(Win count): 76, 승리비율(Win ratio): 38.1910
# 반복(Epoch): 199, 에러(err): 0.5205, 승리횟수(Win count): 76, 승리비율(Win ratio): 38.0000
# 반복(Epoch): 200, 에러(err): 0.2578, 승리횟수(Win count): 77, 승리비율(Win ratio): 38.3085
# 반복(Epoch): 201, 에러(err): 0.2928, 승리횟수(Win count): 78, 승리비율(Win ratio): 38.6139
# /content/model.ckpt-201 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 202, 에러(err): 0.1362, 승리횟수(Win count): 78, 승리비율(Win ratio): 38.4236
# 반복(Epoch): 203, 에러(err): 0.2605, 승리횟수(Win count): 79, 승리비율(Win ratio): 38.7255
# 반복(Epoch): 204, 에러(err): 0.3407, 승리횟수(Win count): 80, 승리비율(Win ratio): 39.0244
# 반복(Epoch): 205, 에러(err): 0.2840, 승리횟수(Win count): 81, 승리비율(Win ratio): 39.3204
# 반복(Epoch): 206, 에러(err): 0.1738, 승리횟수(Win count): 82, 승리비율(Win ratio): 39.6135
# 반복(Epoch): 207, 에러(err): 0.2520, 승리횟수(Win count): 82, 승리비율(Win ratio): 39.4231
# 반복(Epoch): 208, 에러(err): 0.1302, 승리횟수(Win count): 82, 승리비율(Win ratio): 39.2344
# 반복(Epoch): 209, 에러(err): 0.2074, 승리횟수(Win count): 83, 승리비율(Win ratio): 39.5238
# 반복(Epoch): 210, 에러(err): 0.1586, 승리횟수(Win count): 84, 승리비율(Win ratio): 39.8104
# 반복(Epoch): 211, 에러(err): 0.1602, 승리횟수(Win count): 85, 승리비율(Win ratio): 40.0943
# 반복(Epoch): 212, 에러(err): 0.2431, 승리횟수(Win count): 85, 승리비율(Win ratio): 39.9061
# 반복(Epoch): 213, 에러(err): 0.2902, 승리횟수(Win count): 86, 승리비율(Win ratio): 40.1869
# 반복(Epoch): 214, 에러(err): 0.2488, 승리횟수(Win count): 87, 승리비율(Win ratio): 40.4651
# 반복(Epoch): 215, 에러(err): 0.1824, 승리횟수(Win count): 87, 승리비율(Win ratio): 40.2778
# 반복(Epoch): 216, 에러(err): 0.2502, 승리횟수(Win count): 87, 승리비율(Win ratio): 40.0922
# 반복(Epoch): 217, 에러(err): 0.1737, 승리횟수(Win count): 87, 승리비율(Win ratio): 39.9083
# 반복(Epoch): 218, 에러(err): 0.2499, 승리횟수(Win count): 87, 승리비율(Win ratio): 39.7260
# 반복(Epoch): 219, 에러(err): 0.2765, 승리횟수(Win count): 88, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 220, 에러(err): 0.2500, 승리횟수(Win count): 89, 승리비율(Win ratio): 40.2715
# 반복(Epoch): 221, 에러(err): 0.2370, 승리횟수(Win count): 89, 승리비율(Win ratio): 40.0901
# 반복(Epoch): 222, 에러(err): 0.3769, 승리횟수(Win count): 90, 승리비율(Win ratio): 40.3587
# 반복(Epoch): 223, 에러(err): 0.1661, 승리횟수(Win count): 90, 승리비율(Win ratio): 40.1786
# 반복(Epoch): 224, 에러(err): 0.4013, 승리횟수(Win count): 90, 승리비율(Win ratio): 40.0000
# 반복(Epoch): 225, 에러(err): 0.1894, 승리횟수(Win count): 91, 승리비율(Win ratio): 40.2655
# 반복(Epoch): 226, 에러(err): 0.2179, 승리횟수(Win count): 92, 승리비율(Win ratio): 40.5286
# 반복(Epoch): 227, 에러(err): 0.2408, 승리횟수(Win count): 93, 승리비율(Win ratio): 40.7895
# 반복(Epoch): 228, 에러(err): 0.1448, 승리횟수(Win count): 93, 승리비율(Win ratio): 40.6114
# 반복(Epoch): 229, 에러(err): 0.3912, 승리횟수(Win count): 93, 승리비율(Win ratio): 40.4348
# 반복(Epoch): 230, 에러(err): 0.4166, 승리횟수(Win count): 94, 승리비율(Win ratio): 40.6926
# 반복(Epoch): 231, 에러(err): 0.1598, 승리횟수(Win count): 94, 승리비율(Win ratio): 40.5172
# 반복(Epoch): 232, 에러(err): 0.3000, 승리횟수(Win count): 95, 승리비율(Win ratio): 40.7725
# 반복(Epoch): 233, 에러(err): 0.1592, 승리횟수(Win count): 95, 승리비율(Win ratio): 40.5983
# 반복(Epoch): 234, 에러(err): 0.1657, 승리횟수(Win count): 96, 승리비율(Win ratio): 40.8511
# 반복(Epoch): 235, 에러(err): 0.2686, 승리횟수(Win count): 96, 승리비율(Win ratio): 40.6780
# 반복(Epoch): 236, 에러(err): 0.2424, 승리횟수(Win count): 97, 승리비율(Win ratio): 40.9283
# 반복(Epoch): 237, 에러(err): 0.1855, 승리횟수(Win count): 97, 승리비율(Win ratio): 40.7563
# 반복(Epoch): 238, 에러(err): 0.1965, 승리횟수(Win count): 97, 승리비율(Win ratio): 40.5858
# 반복(Epoch): 239, 에러(err): 0.2098, 승리횟수(Win count): 97, 승리비율(Win ratio): 40.4167
# 반복(Epoch): 240, 에러(err): 0.3392, 승리횟수(Win count): 98, 승리비율(Win ratio): 40.6639
# 반복(Epoch): 241, 에러(err): 0.4256, 승리횟수(Win count): 99, 승리비율(Win ratio): 40.9091
# 반복(Epoch): 242, 에러(err): 0.3082, 승리횟수(Win count): 100, 승리비율(Win ratio): 41.1523
# 반복(Epoch): 243, 에러(err): 0.2957, 승리횟수(Win count): 101, 승리비율(Win ratio): 41.3934
# 반복(Epoch): 244, 에러(err): 0.1840, 승리횟수(Win count): 102, 승리비율(Win ratio): 41.6327
# 반복(Epoch): 245, 에러(err): 0.1322, 승리횟수(Win count): 103, 승리비율(Win ratio): 41.8699
# 반복(Epoch): 246, 에러(err): 0.1386, 승리횟수(Win count): 103, 승리비율(Win ratio): 41.7004
# 반복(Epoch): 247, 에러(err): 0.2267, 승리횟수(Win count): 103, 승리비율(Win ratio): 41.5323
# 반복(Epoch): 248, 에러(err): 0.1788, 승리횟수(Win count): 104, 승리비율(Win ratio): 41.7671
# 반복(Epoch): 249, 에러(err): 0.1206, 승리횟수(Win count): 105, 승리비율(Win ratio): 42.0000
# 반복(Epoch): 250, 에러(err): 0.3261, 승리횟수(Win count): 105, 승리비율(Win ratio): 41.8327
# 반복(Epoch): 251, 에러(err): 0.1625, 승리횟수(Win count): 105, 승리비율(Win ratio): 41.6667
# 반복(Epoch): 252, 에러(err): 0.1364, 승리횟수(Win count): 106, 승리비율(Win ratio): 41.8972
# 반복(Epoch): 253, 에러(err): 0.3139, 승리횟수(Win count): 106, 승리비율(Win ratio): 41.7323
# 반복(Epoch): 254, 에러(err): 0.1409, 승리횟수(Win count): 107, 승리비율(Win ratio): 41.9608
# 반복(Epoch): 255, 에러(err): 0.2357, 승리횟수(Win count): 107, 승리비율(Win ratio): 41.7969
# 반복(Epoch): 256, 에러(err): 0.1352, 승리횟수(Win count): 108, 승리비율(Win ratio): 42.0233
# 반복(Epoch): 257, 에러(err): 0.1972, 승리횟수(Win count): 109, 승리비율(Win ratio): 42.2481
# 반복(Epoch): 258, 에러(err): 0.1693, 승리횟수(Win count): 110, 승리비율(Win ratio): 42.4710
# 반복(Epoch): 259, 에러(err): 0.2794, 승리횟수(Win count): 111, 승리비율(Win ratio): 42.6923
# 반복(Epoch): 260, 에러(err): 0.2518, 승리횟수(Win count): 111, 승리비율(Win ratio): 42.5287
# 반복(Epoch): 261, 에러(err): 0.1582, 승리횟수(Win count): 112, 승리비율(Win ratio): 42.7481
# 반복(Epoch): 262, 에러(err): 0.2626, 승리횟수(Win count): 113, 승리비율(Win ratio): 42.9658
# 반복(Epoch): 263, 에러(err): 0.1424, 승리횟수(Win count): 113, 승리비율(Win ratio): 42.8030
# 반복(Epoch): 264, 에러(err): 0.2515, 승리횟수(Win count): 113, 승리비율(Win ratio): 42.6415
# 반복(Epoch): 265, 에러(err): 0.1299, 승리횟수(Win count): 114, 승리비율(Win ratio): 42.8571
# 반복(Epoch): 266, 에러(err): 0.4320, 승리횟수(Win count): 114, 승리비율(Win ratio): 42.6966
# 반복(Epoch): 267, 에러(err): 0.1946, 승리횟수(Win count): 114, 승리비율(Win ratio): 42.5373
# 반복(Epoch): 268, 에러(err): 0.3041, 승리횟수(Win count): 114, 승리비율(Win ratio): 42.3792
# 반복(Epoch): 269, 에러(err): 0.1638, 승리횟수(Win count): 115, 승리비율(Win ratio): 42.5926
# 반복(Epoch): 270, 에러(err): 0.1548, 승리횟수(Win count): 116, 승리비율(Win ratio): 42.8044
# 반복(Epoch): 271, 에러(err): 0.1968, 승리횟수(Win count): 117, 승리비율(Win ratio): 43.0147
# 반복(Epoch): 272, 에러(err): 0.1042, 승리횟수(Win count): 118, 승리비율(Win ratio): 43.2234
# 반복(Epoch): 273, 에러(err): 0.2320, 승리횟수(Win count): 119, 승리비율(Win ratio): 43.4307
# 반복(Epoch): 274, 에러(err): 0.1600, 승리횟수(Win count): 120, 승리비율(Win ratio): 43.6364
# 반복(Epoch): 275, 에러(err): 0.2609, 승리횟수(Win count): 121, 승리비율(Win ratio): 43.8406
# 반복(Epoch): 276, 에러(err): 0.1974, 승리횟수(Win count): 122, 승리비율(Win ratio): 44.0433
# 반복(Epoch): 277, 에러(err): 0.4149, 승리횟수(Win count): 123, 승리비율(Win ratio): 44.2446
# 반복(Epoch): 278, 에러(err): 0.2224, 승리횟수(Win count): 124, 승리비율(Win ratio): 44.4444
# 반복(Epoch): 279, 에러(err): 0.2256, 승리횟수(Win count): 125, 승리비율(Win ratio): 44.6429
# 반복(Epoch): 280, 에러(err): 0.2176, 승리횟수(Win count): 126, 승리비율(Win ratio): 44.8399
# 반복(Epoch): 281, 에러(err): 0.2880, 승리횟수(Win count): 127, 승리비율(Win ratio): 45.0355
# 반복(Epoch): 282, 에러(err): 0.1707, 승리횟수(Win count): 128, 승리비율(Win ratio): 45.2297
# 반복(Epoch): 283, 에러(err): 0.1985, 승리횟수(Win count): 129, 승리비율(Win ratio): 45.4225
# 반복(Epoch): 284, 에러(err): 0.1067, 승리횟수(Win count): 130, 승리비율(Win ratio): 45.6140
# 반복(Epoch): 285, 에러(err): 0.2322, 승리횟수(Win count): 130, 승리비율(Win ratio): 45.4545
# 반복(Epoch): 286, 에러(err): 0.1077, 승리횟수(Win count): 131, 승리비율(Win ratio): 45.6446
# 반복(Epoch): 287, 에러(err): 0.0976, 승리횟수(Win count): 132, 승리비율(Win ratio): 45.8333
# 반복(Epoch): 288, 에러(err): 0.2439, 승리횟수(Win count): 133, 승리비율(Win ratio): 46.0208
# 반복(Epoch): 289, 에러(err): 0.2491, 승리횟수(Win count): 133, 승리비율(Win ratio): 45.8621
# 반복(Epoch): 290, 에러(err): 0.1171, 승리횟수(Win count): 134, 승리비율(Win ratio): 46.0481
# 반복(Epoch): 291, 에러(err): 0.1246, 승리횟수(Win count): 135, 승리비율(Win ratio): 46.2329
# 반복(Epoch): 292, 에러(err): 0.3238, 승리횟수(Win count): 136, 승리비율(Win ratio): 46.4164
# 반복(Epoch): 293, 에러(err): 0.2261, 승리횟수(Win count): 137, 승리비율(Win ratio): 46.5986
# 반복(Epoch): 294, 에러(err): 0.1051, 승리횟수(Win count): 138, 승리비율(Win ratio): 46.7797
# 반복(Epoch): 295, 에러(err): 0.1122, 승리횟수(Win count): 139, 승리비율(Win ratio): 46.9595
# 반복(Epoch): 296, 에러(err): 0.0574, 승리횟수(Win count): 140, 승리비율(Win ratio): 47.1380
# 반복(Epoch): 297, 에러(err): 0.2049, 승리횟수(Win count): 141, 승리비율(Win ratio): 47.3154
# 반복(Epoch): 298, 에러(err): 0.2050, 승리횟수(Win count): 142, 승리비율(Win ratio): 47.4916
# 반복(Epoch): 299, 에러(err): 0.0594, 승리횟수(Win count): 143, 승리비율(Win ratio): 47.6667
# 반복(Epoch): 300, 에러(err): 0.1358, 승리횟수(Win count): 144, 승리비율(Win ratio): 47.8405
# 반복(Epoch): 301, 에러(err): 0.1648, 승리횟수(Win count): 145, 승리비율(Win ratio): 48.0132
# /content/model.ckpt-301 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 302, 에러(err): 0.0658, 승리횟수(Win count): 145, 승리비율(Win ratio): 47.8548
# 반복(Epoch): 303, 에러(err): 0.1444, 승리횟수(Win count): 146, 승리비율(Win ratio): 48.0263
# 반복(Epoch): 304, 에러(err): 0.2097, 승리횟수(Win count): 147, 승리비율(Win ratio): 48.1967
# 반복(Epoch): 305, 에러(err): 0.0992, 승리횟수(Win count): 147, 승리비율(Win ratio): 48.0392
# 반복(Epoch): 306, 에러(err): 0.1797, 승리횟수(Win count): 148, 승리비율(Win ratio): 48.2085
# 반복(Epoch): 307, 에러(err): 0.1559, 승리횟수(Win count): 149, 승리비율(Win ratio): 48.3766
# 반복(Epoch): 308, 에러(err): 0.0579, 승리횟수(Win count): 150, 승리비율(Win ratio): 48.5437
# 반복(Epoch): 309, 에러(err): 0.0893, 승리횟수(Win count): 151, 승리비율(Win ratio): 48.7097
# 반복(Epoch): 310, 에러(err): 0.0888, 승리횟수(Win count): 152, 승리비율(Win ratio): 48.8746
# 반복(Epoch): 311, 에러(err): 0.0643, 승리횟수(Win count): 153, 승리비율(Win ratio): 49.0385
# 반복(Epoch): 312, 에러(err): 0.1507, 승리횟수(Win count): 154, 승리비율(Win ratio): 49.2013
# 반복(Epoch): 313, 에러(err): 0.1056, 승리횟수(Win count): 155, 승리비율(Win ratio): 49.3631
# 반복(Epoch): 314, 에러(err): 0.1170, 승리횟수(Win count): 156, 승리비율(Win ratio): 49.5238
# 반복(Epoch): 315, 에러(err): 0.1254, 승리횟수(Win count): 156, 승리비율(Win ratio): 49.3671
# 반복(Epoch): 316, 에러(err): 0.1671, 승리횟수(Win count): 157, 승리비율(Win ratio): 49.5268
# 반복(Epoch): 317, 에러(err): 0.1479, 승리횟수(Win count): 158, 승리비율(Win ratio): 49.6855
# 반복(Epoch): 318, 에러(err): 0.0787, 승리횟수(Win count): 159, 승리비율(Win ratio): 49.8433
# 반복(Epoch): 319, 에러(err): 0.2100, 승리횟수(Win count): 160, 승리비율(Win ratio): 50.0000
# 반복(Epoch): 320, 에러(err): 0.1503, 승리횟수(Win count): 161, 승리비율(Win ratio): 50.1558
# 반복(Epoch): 321, 에러(err): 0.1085, 승리횟수(Win count): 162, 승리비율(Win ratio): 50.3106
# 반복(Epoch): 322, 에러(err): 0.0921, 승리횟수(Win count): 162, 승리비율(Win ratio): 50.1548
# 반복(Epoch): 323, 에러(err): 0.1747, 승리횟수(Win count): 163, 승리비율(Win ratio): 50.3086
# 반복(Epoch): 324, 에러(err): 0.1118, 승리횟수(Win count): 164, 승리비율(Win ratio): 50.4615
# 반복(Epoch): 325, 에러(err): 0.0609, 승리횟수(Win count): 165, 승리비율(Win ratio): 50.6135
# 반복(Epoch): 326, 에러(err): 0.0601, 승리횟수(Win count): 166, 승리비율(Win ratio): 50.7645
# 반복(Epoch): 327, 에러(err): 0.1662, 승리횟수(Win count): 167, 승리비율(Win ratio): 50.9146
# 반복(Epoch): 328, 에러(err): 0.1546, 승리횟수(Win count): 168, 승리비율(Win ratio): 51.0638
# 반복(Epoch): 329, 에러(err): 0.1325, 승리횟수(Win count): 169, 승리비율(Win ratio): 51.2121
# 반복(Epoch): 330, 에러(err): 0.1140, 승리횟수(Win count): 170, 승리비율(Win ratio): 51.3595
# 반복(Epoch): 331, 에러(err): 0.1041, 승리횟수(Win count): 171, 승리비율(Win ratio): 51.5060
# 반복(Epoch): 332, 에러(err): 0.1029, 승리횟수(Win count): 172, 승리비율(Win ratio): 51.6517
# 반복(Epoch): 333, 에러(err): 0.0625, 승리횟수(Win count): 173, 승리비율(Win ratio): 51.7964
# 반복(Epoch): 334, 에러(err): 0.0335, 승리횟수(Win count): 174, 승리비율(Win ratio): 51.9403
# 반복(Epoch): 335, 에러(err): 0.0596, 승리횟수(Win count): 175, 승리비율(Win ratio): 52.0833
# 반복(Epoch): 336, 에러(err): 0.1056, 승리횟수(Win count): 176, 승리비율(Win ratio): 52.2255
# 반복(Epoch): 337, 에러(err): 0.0549, 승리횟수(Win count): 176, 승리비율(Win ratio): 52.0710
# 반복(Epoch): 338, 에러(err): 0.0980, 승리횟수(Win count): 177, 승리비율(Win ratio): 52.2124
# 반복(Epoch): 339, 에러(err): 0.0321, 승리횟수(Win count): 178, 승리비율(Win ratio): 52.3529
# 반복(Epoch): 340, 에러(err): 0.0833, 승리횟수(Win count): 179, 승리비율(Win ratio): 52.4927
# 반복(Epoch): 341, 에러(err): 0.0329, 승리횟수(Win count): 180, 승리비율(Win ratio): 52.6316
# 반복(Epoch): 342, 에러(err): 0.1234, 승리횟수(Win count): 181, 승리비율(Win ratio): 52.7697
# 반복(Epoch): 343, 에러(err): 0.0893, 승리횟수(Win count): 182, 승리비율(Win ratio): 52.9070
# 반복(Epoch): 344, 에러(err): 0.0329, 승리횟수(Win count): 183, 승리비율(Win ratio): 53.0435
# 반복(Epoch): 345, 에러(err): 0.0447, 승리횟수(Win count): 184, 승리비율(Win ratio): 53.1792
# 반복(Epoch): 346, 에러(err): 0.0310, 승리횟수(Win count): 185, 승리비율(Win ratio): 53.3141
# 반복(Epoch): 347, 에러(err): 0.0228, 승리횟수(Win count): 186, 승리비율(Win ratio): 53.4483
# 반복(Epoch): 348, 에러(err): 0.0373, 승리횟수(Win count): 186, 승리비율(Win ratio): 53.2951
# 반복(Epoch): 349, 에러(err): 0.1618, 승리횟수(Win count): 187, 승리비율(Win ratio): 53.4286
# 반복(Epoch): 350, 에러(err): 0.0850, 승리횟수(Win count): 188, 승리비율(Win ratio): 53.5613
# 반복(Epoch): 351, 에러(err): 0.1116, 승리횟수(Win count): 189, 승리비율(Win ratio): 53.6932
# 반복(Epoch): 352, 에러(err): 0.0999, 승리횟수(Win count): 190, 승리비율(Win ratio): 53.8244
# 반복(Epoch): 353, 에러(err): 0.1133, 승리횟수(Win count): 191, 승리비율(Win ratio): 53.9548
# 반복(Epoch): 354, 에러(err): 0.0968, 승리횟수(Win count): 192, 승리비율(Win ratio): 54.0845
# 반복(Epoch): 355, 에러(err): 0.0587, 승리횟수(Win count): 193, 승리비율(Win ratio): 54.2135
# 반복(Epoch): 356, 에러(err): 0.0459, 승리횟수(Win count): 193, 승리비율(Win ratio): 54.0616
# 반복(Epoch): 357, 에러(err): 0.0453, 승리횟수(Win count): 194, 승리비율(Win ratio): 54.1899
# 반복(Epoch): 358, 에러(err): 0.0510, 승리횟수(Win count): 195, 승리비율(Win ratio): 54.3175
# 반복(Epoch): 359, 에러(err): 0.0560, 승리횟수(Win count): 196, 승리비율(Win ratio): 54.4444
# 반복(Epoch): 360, 에러(err): 0.0860, 승리횟수(Win count): 197, 승리비율(Win ratio): 54.5706
# 반복(Epoch): 361, 에러(err): 0.0530, 승리횟수(Win count): 198, 승리비율(Win ratio): 54.6961
# 반복(Epoch): 362, 에러(err): 0.1164, 승리횟수(Win count): 199, 승리비율(Win ratio): 54.8209
# 반복(Epoch): 363, 에러(err): 0.1215, 승리횟수(Win count): 200, 승리비율(Win ratio): 54.9451
# 반복(Epoch): 364, 에러(err): 0.1131, 승리횟수(Win count): 201, 승리비율(Win ratio): 55.0685
# 반복(Epoch): 365, 에러(err): 0.3577, 승리횟수(Win count): 202, 승리비율(Win ratio): 55.1913
# 반복(Epoch): 366, 에러(err): 0.1559, 승리횟수(Win count): 203, 승리비율(Win ratio): 55.3134
# 반복(Epoch): 367, 에러(err): 0.0716, 승리횟수(Win count): 204, 승리비율(Win ratio): 55.4348
# 반복(Epoch): 368, 에러(err): 0.0660, 승리횟수(Win count): 205, 승리비율(Win ratio): 55.5556
# 반복(Epoch): 369, 에러(err): 0.0803, 승리횟수(Win count): 205, 승리비율(Win ratio): 55.4054
# 반복(Epoch): 370, 에러(err): 0.0487, 승리횟수(Win count): 206, 승리비율(Win ratio): 55.5256
# 반복(Epoch): 371, 에러(err): 0.1126, 승리횟수(Win count): 207, 승리비율(Win ratio): 55.6452
# 반복(Epoch): 372, 에러(err): 0.3172, 승리횟수(Win count): 207, 승리비율(Win ratio): 55.4960
# 반복(Epoch): 373, 에러(err): 0.1661, 승리횟수(Win count): 207, 승리비율(Win ratio): 55.3476
# 반복(Epoch): 374, 에러(err): 0.0483, 승리횟수(Win count): 208, 승리비율(Win ratio): 55.4667
# 반복(Epoch): 375, 에러(err): 0.0408, 승리횟수(Win count): 208, 승리비율(Win ratio): 55.3191
# 반복(Epoch): 376, 에러(err): 0.0599, 승리횟수(Win count): 209, 승리비율(Win ratio): 55.4377
# 반복(Epoch): 377, 에러(err): 0.0889, 승리횟수(Win count): 210, 승리비율(Win ratio): 55.5556
# 반복(Epoch): 378, 에러(err): 0.1677, 승리횟수(Win count): 211, 승리비율(Win ratio): 55.6728
# 반복(Epoch): 379, 에러(err): 0.0632, 승리횟수(Win count): 212, 승리비율(Win ratio): 55.7895
# 반복(Epoch): 380, 에러(err): 0.0643, 승리횟수(Win count): 213, 승리비율(Win ratio): 55.9055
# 반복(Epoch): 381, 에러(err): 0.0428, 승리횟수(Win count): 214, 승리비율(Win ratio): 56.0209
# 반복(Epoch): 382, 에러(err): 0.1082, 승리횟수(Win count): 215, 승리비율(Win ratio): 56.1358
# 반복(Epoch): 383, 에러(err): 0.0489, 승리횟수(Win count): 216, 승리비율(Win ratio): 56.2500
# 반복(Epoch): 384, 에러(err): 0.0518, 승리횟수(Win count): 217, 승리비율(Win ratio): 56.3636
# 반복(Epoch): 385, 에러(err): 0.0387, 승리횟수(Win count): 218, 승리비율(Win ratio): 56.4767
# 반복(Epoch): 386, 에러(err): 0.0929, 승리횟수(Win count): 218, 승리비율(Win ratio): 56.3307
# 반복(Epoch): 387, 에러(err): 0.0473, 승리횟수(Win count): 219, 승리비율(Win ratio): 56.4433
# 반복(Epoch): 388, 에러(err): 0.1069, 승리횟수(Win count): 220, 승리비율(Win ratio): 56.5553
# 반복(Epoch): 389, 에러(err): 0.0765, 승리횟수(Win count): 221, 승리비율(Win ratio): 56.6667
# 반복(Epoch): 390, 에러(err): 0.0721, 승리횟수(Win count): 222, 승리비율(Win ratio): 56.7775
# 반복(Epoch): 391, 에러(err): 0.0694, 승리횟수(Win count): 223, 승리비율(Win ratio): 56.8878
# 반복(Epoch): 392, 에러(err): 0.0784, 승리횟수(Win count): 223, 승리비율(Win ratio): 56.7430
# 반복(Epoch): 393, 에러(err): 0.0406, 승리횟수(Win count): 224, 승리비율(Win ratio): 56.8528
# 반복(Epoch): 394, 에러(err): 0.0609, 승리횟수(Win count): 225, 승리비율(Win ratio): 56.9620
# 반복(Epoch): 395, 에러(err): 0.0322, 승리횟수(Win count): 226, 승리비율(Win ratio): 57.0707
# 반복(Epoch): 396, 에러(err): 0.0693, 승리횟수(Win count): 227, 승리비율(Win ratio): 57.1788
# 반복(Epoch): 397, 에러(err): 0.0365, 승리횟수(Win count): 228, 승리비율(Win ratio): 57.2864
# 반복(Epoch): 398, 에러(err): 0.0453, 승리횟수(Win count): 229, 승리비율(Win ratio): 57.3935
# 반복(Epoch): 399, 에러(err): 0.0535, 승리횟수(Win count): 230, 승리비율(Win ratio): 57.5000
# 반복(Epoch): 400, 에러(err): 0.0410, 승리횟수(Win count): 231, 승리비율(Win ratio): 57.6060
# 반복(Epoch): 401, 에러(err): 0.0341, 승리횟수(Win count): 232, 승리비율(Win ratio): 57.7114
# /content/model.ckpt-401 경로에 파라미터가 저장되었습니다
# 반복(Epoch): 402, 에러(err): 0.0395, 승리횟수(Win count): 233, 승리비율(Win ratio): 57.8164
# 반복(Epoch): 403, 에러(err): 0.0184, 승리횟수(Win count): 234, 승리비율(Win ratio): 57.9208
# 반복(Epoch): 404, 에러(err): 0.0657, 승리횟수(Win count): 235, 승리비율(Win ratio): 58.0247
# 반복(Epoch): 405, 에러(err): 0.0262, 승리횟수(Win count): 236, 승리비율(Win ratio): 58.1281
# 반복(Epoch): 406, 에러(err): 0.0326, 승리횟수(Win count): 237, 승리비율(Win ratio): 58.2310
# 반복(Epoch): 407, 에러(err): 0.0445, 승리횟수(Win count): 238, 승리비율(Win ratio): 58.3333
# 반복(Epoch): 408, 에러(err): 0.0411, 승리횟수(Win count): 239, 승리비율(Win ratio): 58.4352
# 반복(Epoch): 409, 에러(err): 0.0420, 승리횟수(Win count): 240, 승리비율(Win ratio): 58.5366
# 반복(Epoch): 410, 에러(err): 0.0351, 승리횟수(Win count): 241, 승리비율(Win ratio): 58.6375
# 반복(Epoch): 411, 에러(err): 0.0409, 승리횟수(Win count): 242, 승리비율(Win ratio): 58.7379
# 반복(Epoch): 412, 에러(err): 0.0887, 승리횟수(Win count): 243, 승리비율(Win ratio): 58.8378
# 반복(Epoch): 413, 에러(err): 0.0568, 승리횟수(Win count): 244, 승리비율(Win ratio): 58.9372
# 반복(Epoch): 414, 에러(err): 0.0564, 승리횟수(Win count): 245, 승리비율(Win ratio): 59.0361
# 반복(Epoch): 415, 에러(err): 0.0658, 승리횟수(Win count): 246, 승리비율(Win ratio): 59.1346
# 반복(Epoch): 416, 에러(err): 0.0388, 승리횟수(Win count): 247, 승리비율(Win ratio): 59.2326
# 반복(Epoch): 417, 에러(err): 0.0650, 승리횟수(Win count): 248, 승리비율(Win ratio): 59.3301
# 반복(Epoch): 418, 에러(err): 0.0710, 승리횟수(Win count): 249, 승리비율(Win ratio): 59.4272
# 반복(Epoch): 419, 에러(err): 0.0270, 승리횟수(Win count): 250, 승리비율(Win ratio): 59.5238
# 반복(Epoch): 420, 에러(err): 0.0449, 승리횟수(Win count): 251, 승리비율(Win ratio): 59.6200
# 반복(Epoch): 421, 에러(err): 0.0222, 승리횟수(Win count): 252, 승리비율(Win ratio): 59.7156
# 반복(Epoch): 422, 에러(err): 0.0401, 승리횟수(Win count): 253, 승리비율(Win ratio): 59.8109
# 반복(Epoch): 423, 에러(err): 0.0486, 승리횟수(Win count): 254, 승리비율(Win ratio): 59.9057
# 반복(Epoch): 424, 에러(err): 0.0409, 승리횟수(Win count): 255, 승리비율(Win ratio): 60.0000
# 반복(Epoch): 425, 에러(err): 0.0405, 승리횟수(Win count): 256, 승리비율(Win ratio): 60.0939
# 반복(Epoch): 426, 에러(err): 0.0309, 승리횟수(Win count): 257, 승리비율(Win ratio): 60.1874
# 반복(Epoch): 427, 에러(err): 0.0289, 승리횟수(Win count): 258, 승리비율(Win ratio): 60.2804
# 반복(Epoch): 428, 에러(err): 0.0372, 승리횟수(Win count): 259, 승리비율(Win ratio): 60.3730
# 반복(Epoch): 429, 에러(err): 0.0161, 승리횟수(Win count): 260, 승리비율(Win ratio): 60.4651
# 반복(Epoch): 430, 에러(err): 0.0325, 승리횟수(Win count): 261, 승리비율(Win ratio): 60.5568
# 반복(Epoch): 431, 에러(err): 0.0160, 승리횟수(Win count): 262, 승리비율(Win ratio): 60.6481
# 반복(Epoch): 432, 에러(err): 0.0320, 승리횟수(Win count): 263, 승리비율(Win ratio): 60.7390
# 반복(Epoch): 433, 에러(err): 0.0151, 승리횟수(Win count): 264, 승리비율(Win ratio): 60.8295
# 반복(Epoch): 434, 에러(err): 0.0148, 승리횟수(Win count): 265, 승리비율(Win ratio): 60.9195
# 반복(Epoch): 435, 에러(err): 0.0280, 승리횟수(Win count): 266, 승리비율(Win ratio): 61.0092
# 반복(Epoch): 436, 에러(err): 0.0115, 승리횟수(Win count): 267, 승리비율(Win ratio): 61.0984
# 반복(Epoch): 437, 에러(err): 0.0112, 승리횟수(Win count): 268, 승리비율(Win ratio): 61.1872
# 반복(Epoch): 438, 에러(err): 0.0094, 승리횟수(Win count): 269, 승리비율(Win ratio): 61.2756
# 반복(Epoch): 439, 에러(err): 0.0117, 승리횟수(Win count): 270, 승리비율(Win ratio): 61.3636
# 반복(Epoch): 440, 에러(err): 0.0130, 승리횟수(Win count): 271, 승리비율(Win ratio): 61.4512
# 반복(Epoch): 441, 에러(err): 0.0078, 승리횟수(Win count): 272, 승리비율(Win ratio): 61.5385
# 반복(Epoch): 442, 에러(err): 0.0120, 승리횟수(Win count): 273, 승리비율(Win ratio): 61.6253
# 반복(Epoch): 443, 에러(err): 0.0101, 승리횟수(Win count): 274, 승리비율(Win ratio): 61.7117
# 반복(Epoch): 444, 에러(err): 0.0101, 승리횟수(Win count): 275, 승리비율(Win ratio): 61.7978
# 반복(Epoch): 445, 에러(err): 0.0103, 승리횟수(Win count): 276, 승리비율(Win ratio): 61.8834
# 반복(Epoch): 446, 에러(err): 0.0074, 승리횟수(Win count): 277, 승리비율(Win ratio): 61.9687
# 반복(Epoch): 447, 에러(err): 0.0099, 승리횟수(Win count): 278, 승리비율(Win ratio): 62.0536
# 반복(Epoch): 448, 에러(err): 0.0078, 승리횟수(Win count): 279, 승리비율(Win ratio): 62.1381
# 반복(Epoch): 449, 에러(err): 0.0064, 승리횟수(Win count): 280, 승리비율(Win ratio): 62.2222
# 반복(Epoch): 450, 에러(err): 0.0073, 승리횟수(Win count): 281, 승리비율(Win ratio): 62.3060
# 반복(Epoch): 451, 에러(err): 0.0098, 승리횟수(Win count): 282, 승리비율(Win ratio): 62.3894
# 반복(Epoch): 452, 에러(err): 0.0128, 승리횟수(Win count): 283, 승리비율(Win ratio): 62.4724
# 반복(Epoch): 453, 에러(err): 0.0087, 승리횟수(Win count): 284, 승리비율(Win ratio): 62.5551
# 반복(Epoch): 454, 에러(err): 0.0081, 승리횟수(Win count): 285, 승리비율(Win ratio): 62.6374
# 반복(Epoch): 455, 에러(err): 0.0073, 승리횟수(Win count): 286, 승리비율(Win ratio): 62.7193
# 반복(Epoch): 456, 에러(err): 0.0086, 승리횟수(Win count): 287, 승리비율(Win ratio): 62.8009
# 반복(Epoch): 457, 에러(err): 0.0071, 승리횟수(Win count): 288, 승리비율(Win ratio): 62.8821
# 반복(Epoch): 458, 에러(err): 0.0115, 승리횟수(Win count): 289, 승리비율(Win ratio): 62.9630
# 반복(Epoch): 459, 에러(err): 0.0088, 승리횟수(Win count): 290, 승리비율(Win ratio): 63.0435
# 반복(Epoch): 460, 에러(err): 0.0079, 승리횟수(Win count): 291, 승리비율(Win ratio): 63.1236
# 반복(Epoch): 461, 에러(err): 0.0073, 승리횟수(Win count): 292, 승리비율(Win ratio): 63.2035
# 반복(Epoch): 462, 에러(err): 0.0054, 승리횟수(Win count): 293, 승리비율(Win ratio): 63.2829
# 반복(Epoch): 463, 에러(err): 0.0088, 승리횟수(Win count): 294, 승리비율(Win ratio): 63.3621
# 반복(Epoch): 464, 에러(err): 0.0067, 승리횟수(Win count): 295, 승리비율(Win ratio): 63.4409
# 반복(Epoch): 465, 에러(err): 0.0060, 승리횟수(Win count): 296, 승리비율(Win ratio): 63.5193
# 반복(Epoch): 466, 에러(err): 0.0066, 승리횟수(Win count): 297, 승리비율(Win ratio): 63.5974
# 반복(Epoch): 467, 에러(err): 0.0063, 승리횟수(Win count): 298, 승리비율(Win ratio): 63.6752
# 반복(Epoch): 468, 에러(err): 0.0053, 승리횟수(Win count): 299, 승리비율(Win ratio): 63.7527
# 반복(Epoch): 469, 에러(err): 0.0075, 승리횟수(Win count): 300, 승리비율(Win ratio): 63.8298
# 반복(Epoch): 470, 에러(err): 0.0068, 승리횟수(Win count): 301, 승리비율(Win ratio): 63.9066
# 반복(Epoch): 471, 에러(err): 0.0038, 승리횟수(Win count): 302, 승리비율(Win ratio): 63.9831
# 반복(Epoch): 472, 에러(err): 0.0044, 승리횟수(Win count): 303, 승리비율(Win ratio): 64.0592
# 반복(Epoch): 473, 에러(err): 0.0061, 승리횟수(Win count): 304, 승리비율(Win ratio): 64.1350
# 반복(Epoch): 474, 에러(err): 0.0046, 승리횟수(Win count): 305, 승리비율(Win ratio): 64.2105
# 반복(Epoch): 475, 에러(err): 0.0050, 승리횟수(Win count): 306, 승리비율(Win ratio): 64.2857
# 반복(Epoch): 476, 에러(err): 0.0073, 승리횟수(Win count): 307, 승리비율(Win ratio): 64.3606
# 반복(Epoch): 477, 에러(err): 0.0058, 승리횟수(Win count): 308, 승리비율(Win ratio): 64.4351
# 반복(Epoch): 478, 에러(err): 0.0047, 승리횟수(Win count): 309, 승리비율(Win ratio): 64.5094
# 반복(Epoch): 479, 에러(err): 0.0051, 승리횟수(Win count): 310, 승리비율(Win ratio): 64.5833
# 반복(Epoch): 480, 에러(err): 0.0046, 승리횟수(Win count): 311, 승리비율(Win ratio): 64.6570
# 반복(Epoch): 481, 에러(err): 0.0042, 승리횟수(Win count): 312, 승리비율(Win ratio): 64.7303
# 반복(Epoch): 482, 에러(err): 0.0047, 승리횟수(Win count): 313, 승리비율(Win ratio): 64.8033
# 반복(Epoch): 483, 에러(err): 0.0051, 승리횟수(Win count): 314, 승리비율(Win ratio): 64.8760
# 반복(Epoch): 484, 에러(err): 0.0063, 승리횟수(Win count): 315, 승리비율(Win ratio): 64.9485
# 반복(Epoch): 485, 에러(err): 0.0042, 승리횟수(Win count): 316, 승리비율(Win ratio): 65.0206
# 반복(Epoch): 486, 에러(err): 0.0042, 승리횟수(Win count): 317, 승리비율(Win ratio): 65.0924
# 반복(Epoch): 487, 에러(err): 0.0041, 승리횟수(Win count): 318, 승리비율(Win ratio): 65.1639
# 반복(Epoch): 488, 에러(err): 0.0039, 승리횟수(Win count): 319, 승리비율(Win ratio): 65.2352
# 반복(Epoch): 489, 에러(err): 0.0037, 승리횟수(Win count): 320, 승리비율(Win ratio): 65.3061
# 반복(Epoch): 490, 에러(err): 0.0063, 승리횟수(Win count): 321, 승리비율(Win ratio): 65.3768
# 반복(Epoch): 491, 에러(err): 0.0044, 승리횟수(Win count): 322, 승리비율(Win ratio): 65.4472
# 반복(Epoch): 492, 에러(err): 0.0087, 승리횟수(Win count): 323, 승리비율(Win ratio): 65.5172
# 반복(Epoch): 493, 에러(err): 0.0058, 승리횟수(Win count): 324, 승리비율(Win ratio): 65.5870
# 반복(Epoch): 494, 에러(err): 0.0032, 승리횟수(Win count): 325, 승리비율(Win ratio): 65.6566
# 반복(Epoch): 495, 에러(err): 0.0042, 승리횟수(Win count): 326, 승리비율(Win ratio): 65.7258
# 반복(Epoch): 496, 에러(err): 0.0031, 승리횟수(Win count): 327, 승리비율(Win ratio): 65.7948
# 반복(Epoch): 497, 에러(err): 0.0024, 승리횟수(Win count): 328, 승리비율(Win ratio): 65.8635
# 반복(Epoch): 498, 에러(err): 0.0029, 승리횟수(Win count): 329, 승리비율(Win ratio): 65.9319
# 반복(Epoch): 499, 에러(err): 0.0032, 승리횟수(Win count): 330, 승리비율(Win ratio): 66.0000
# 반복(Epoch): 500, 에러(err): 0.0042, 승리횟수(Win count): 331, 승리비율(Win ratio): 66.0679
# 트레이닝 완료
# /content/model.ckpt-500 경로에 파라미터가 저장되었습니다

# %%
from Chap_12_Reinforced_Learning_Training import CatchEnvironment, DQN
from IPython import display
import matplotlib.patches as patches
import pylab as pl
import time
import tensorflow as tf
import os

# %%
# 설정값들을 정의합니다.
gridSize = 10
maxGames = 30
DQN_model = DQN()
env = CatchEnvironment(gridSize)
winCount = 0
loseCount = 0
numberOfGames = 0

# %%
# 현재 상태를 그리기 위한 drawState 함수를 정의합니다.
def drawState(fruitRow, fruitColumn, basket, gridSize):
  # 과일이 몇번째 세로축에 있는지 정의합니다.
  fruitX = fruitColumn 
  # 과일이 몇번째 가로축에 있는지 정의합니다.
  fruitY = (gridSize - fruitRow + 1)
  # 승리 횟수, 패배 횟수, 전체 게임 횟수를 화면 상단에 출력합니다.
  statusTitle = "Wins: " + str(winCount) + "  Losses: " + str(loseCount) + "  TotalGame: " + str(numberOfGames)
  axis.set_title(statusTitle, fontsize=30)
  for p in [
    # 배경의 위치를 지정합니다.
    patches.Rectangle(
        ((ground - 1), (ground)), 11, 10,
        facecolor="#000000"      # Black
    ),
    # 바구니의 위치를 지정합니다.
    patches.Rectangle(
        (basket - 1, ground), 2, 0.5,
        facecolor="#FF0000"     # Red
    ),
    # 과일의 위치를 지정합니다.
    patches.Rectangle(
        (fruitX - 0.5, fruitY - 0.5), 1, 1,
        facecolor="#0000FF"       # Blue
    ),   
    ]:
      axis.add_patch(p)
  display.clear_output(wait=True)
  display.display(pl.gcf())

# %%
# 저장된 파라미터를 불러옵니다.
ckpt = tf.train.Checkpoint(model=DQN_model)
latest_ckpt = tf.train.latest_checkpoint(os.getcwd())
#latest_ckpt = '/content/model.ckpt-201'

ckpt.restore(latest_ckpt)

print('저장된 파라미터를 불러왔습니다!')
# Out:
# 저장된 파라미터를 불러왔습니다!

# %%
# GIF를 만들기위해 설치합니다.
# !pip install imageio

# !mkdir '/content/generated_output/'

import glob
import imageio
import matplotlib.pyplot as plt
import PIL

def display_image(epoch_no):
  return PIL.Image.open('/content/generated_output/image_at_epoch_{:04d}.png'.format(epoch_no))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.25.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.22.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (8.4.0)

# %%
# 화면을 그리기 위한 설정들을 정의합니다.
ground = 1
plot = pl.figure(figsize=(12,12))
axis = plot.add_subplot(111, aspect='equal')
axis.set_xlim([-1, 12])
axis.set_ylim([0, 12])

frame = 1

# maxGames 횟수만큼 게임을 플레이합니다.
while (numberOfGames < maxGames):
  numberOfGames = numberOfGames + 1

  # 최초의 상태를 정의합니다.
  isGameOver = False
  fruitRow, fruitColumn, basket = env.reset()
  currentState = env.observe()
  drawState(fruitRow, fruitColumn, basket, gridSize)

  while (isGameOver != True):
    # 현재 상태를 DQN의 입력값으로 넣고 구한 Q값중 가장 큰 Q값을 갖는 행동을 취합니다.
    q = DQN_model(currentState).numpy()
    action = q.argmax()

    # 행동을 취하고 다음 상태로 넘어갑니다.
    nextState, reward, gameOver, stateInfo = env.act(action)    
    fruitRow = stateInfo[0]
    fruitColumn = stateInfo[1]
    basket = stateInfo[2]

     # 과일을 받아내면 winCount를 1 늘리고 과일을 받아내지 못하면 loseCount를 1 늘립니다.
    if (reward == 1):
      winCount = winCount + 1
    elif (reward == -1):
      loseCount = loseCount + 1

    currentState = nextState
    isGameOver = gameOver
    drawState(fruitRow, fruitColumn, basket, gridSize)
    # 다음 행동을 취하기 전에 0.05초의 일시정지를 줍니다.
#    time.sleep(5)
    plt.savefig('/content/generated_output/image_at_frame_{:04d}.png'.format(frame))
    frame = frame+1

# 최종 출력결과 이미지를 하나로 정리합니다.
display.clear_output(wait=True)

# %%
anim_file = '/content/generated_output/dcgan.gif'

with imageio.get_writer(anim_file, mode='I') as writer:
  filenames = glob.glob('/content/generated_output/image*.png')
  filenames = sorted(filenames)
  last = -1
  for i,filename in enumerate(filenames):
    frame = 2*(i**0.5)
    if round(frame) > round(last):
      last = frame
    else:
      continue
    image = imageio.imread(filename)
    writer.append_data(image)
  image = imageio.imread(filename)
  writer.append_data(image)

import IPython
if IPython.version_info > (6,2,0,''):
  display.Image(filename=anim_file)
# Out:
# <ipython-input-8-b2b7cd20ce6a>:13: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)
# <ipython-input-8-b2b7cd20ce6a>:15: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(filename)

# %%
from google.colab import files

files.download(anim_file)
# !zip -r /content/file.zip /content/generated_output
files.download("/content/file.zip")
# Out:
#   adding: content/generated_output/ (stored 0%)
#   adding: content/generated_output/image_at_frame_0028.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0015.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0031.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0119.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0036.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0129.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0140.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0027.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0131.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0122.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0042.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0096.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0056.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0072.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0159.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0083.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0136.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0022.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0176.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0059.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0150.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0182.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0203.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0126.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0013.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0127.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0046.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0222.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0064.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0133.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0227.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0039.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0197.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0071.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0125.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0100.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0043.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0113.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0214.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0169.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0107.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0102.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0137.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0199.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0196.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0079.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0151.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0110.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0141.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0193.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0051.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0115.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0097.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0121.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0158.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0058.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0234.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0063.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0215.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0016.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0228.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0106.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0204.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0194.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0239.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0200.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0026.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0218.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0099.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0108.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0098.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0095.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0070.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0237.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0225.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0224.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0065.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0212.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0233.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0105.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0005.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0220.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0112.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0103.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0139.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0080.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0060.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0135.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0068.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0117.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0094.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0062.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0145.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0053.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0057.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0154.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0198.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0008.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0104.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0138.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0033.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0124.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0206.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0157.png (deflated 35%)
#   adding: content/generated_output/dcgan.gif (deflated 19%)
#   adding: content/generated_output/image_at_frame_0073.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0003.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0032.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0086.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0077.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0238.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0168.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0209.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0210.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0055.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0052.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0226.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0240.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0221.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0084.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0164.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0144.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0236.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0123.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0090.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0017.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0189.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0167.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0006.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0175.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0061.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0170.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0002.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0029.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0166.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0091.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0012.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0174.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0118.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0035.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0007.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0190.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0128.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0038.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0087.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0069.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0066.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0161.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0019.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0089.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0185.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0049.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0179.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0192.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0030.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0186.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0134.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0082.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0074.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0231.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0054.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0172.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0230.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0149.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0208.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0232.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0147.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0184.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0207.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0171.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0010.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0195.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0034.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0114.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0085.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0021.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0111.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0088.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0024.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0045.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0130.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0146.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0025.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0116.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0076.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0092.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0213.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0219.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0040.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0009.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0120.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0177.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0183.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0148.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0109.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0143.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0229.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0037.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0018.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0235.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0201.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0078.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0023.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0142.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0191.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0075.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0001.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0047.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0205.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0156.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0020.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0093.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0067.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0180.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0160.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0101.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0163.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0165.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0041.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0202.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0211.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0153.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0014.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0152.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0181.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0011.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0155.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0081.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0004.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0048.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0050.png (deflated 37%)
#   adding: content/generated_output/image_at_frame_0188.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0187.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0162.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0178.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0223.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0044.png (deflated 36%)
#   adding: content/generated_output/image_at_frame_0217.png (deflated 34%)
#   adding: content/generated_output/image_at_frame_0173.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0216.png (deflated 35%)
#   adding: content/generated_output/image_at_frame_0132.png (deflated 35%)
